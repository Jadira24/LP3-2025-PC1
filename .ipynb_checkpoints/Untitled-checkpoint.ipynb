# %% [markdown]
# DETECCIÓN DE CÁNCER DE CUELLO UTERINO (CA_CERVIX)

# %% [markdown]
# IMPORTAR LIBRERÍAS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# CARGAR EL DATASET

# %%
dataframe = pd.read_csv('DSCancerDeCuelloUterinoDatosPerdidos.csv', sep=';')
dataframe.head(10)
# Out:
#    BEHAVIOR_SEXUALRISK  BEHAVIOR_EATING  BEHAVIOR_PERSONALHYGIENE  \
# 0                   10               13                        12
# 1                   10               11                        11
# 2                   10               15                         3
# 3                   10               11                        10
# 4                    8               11                         7
# 5                   10               14                         8
# 6                   10               15                         4
# 7                    8               12                         9
# 8                   10               15                         7
# 9                    7               15                         7
#
#    INTENTION_AGGREGATION  INTENTION_COMMITMENT  ATTITUDE_CONSISTENCY  \
# 0                      4                     7                     9
# 1                     10                    14                     7
# ...
